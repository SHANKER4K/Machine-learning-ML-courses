# %% [markdown]
# ![cyber_photo](cyber_photo.jpg)
#
# Cyber threats are a growing concern for organizations worldwide. These threats take many forms, including malware, phishing, and denial-of-service (DOS) attacks, compromising sensitive information and disrupting operations. The increasing sophistication and frequency of these attacks make it imperative for organizations to adopt advanced security measures. Traditional threat detection methods often fall short due to their inability to adapt to new and evolving threats. This is where deep learning models come into play.
#
# Deep learning models can analyze vast amounts of data and identify patterns that may not be immediately obvious to human analysts. By leveraging these models, organizations can proactively detect and mitigate cyber threats, safeguarding their sensitive information and ensuring operational continuity.
#
# As a cybersecurity analyst, you identify and mitigate these threats. In this project, you will design and implement a deep learning model to detect cyber threats. The BETH dataset simulates real-world logs, providing a rich source of information for training and testing your model. The data has already undergone preprocessing, and we have a target label, `sus_label`, indicating whether an event is malicious (1) or benign (0).
#
# By successfully developing this model, you will contribute to enhancing cybersecurity measures and protecting organizations from potentially devastating cyber attacks.

# %% [markdown]
# ### The Data
#
# | Column     | Description              |
# |------------|--------------------------|
# |`processId`|The unique identifier for the process that generated the event - int64 |
# |`threadId`|ID for the thread spawning the log - int64|
# |`parentProcessId`|Label for the process spawning this log - int64|
# |`userId`|ID of user spawning the log|Numerical - int64|
# |`mountNamespace`|Mounting restrictions the process log works within - int64|
# |`argsNum`|Number of arguments passed to the event - int64|
# |`returnValue`|Value returned from the event log (usually 0) - int64|
# |`sus_label`|Binary label as suspicous event (1 is suspicious, 0 is not) - int64|
#
# More information on the dataset: [BETH dataset](accreditation.md)

# %%
# Import required libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.nn.functional as functional
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
# from torchmetrics import Accuracy
# from sklearn.metrics import accuracy_score  # uncomment to use sklearn

# %%
# Load preprocessed data
train_df = pd.read_csv('labelled_train.csv')
test_df = pd.read_csv('labelled_test.csv')
val_df = pd.read_csv('labelled_validation.csv')

# View the first 5 rows of training set
train_df.head()
# Out:
#    processId  threadId  parentProcessId  userId  mountNamespace  argsNum  \
# 0        381      7337                1     100      4026532231        5
# 1        381      7337                1     100      4026532231        1
# 2        381      7337                1     100      4026532231        0
# 3       7347      7347             7341       0      4026531840        2
# 4       7347      7347             7341       0      4026531840        4
#
#    returnValue  sus_label
# 0            0          1
# 1            0          1
# 2            0          1
# 3           -2          1
# 4            0          1

# %%
X = train_df.drop('sus_label', axis=1).values
y = train_df['sus_label'].values

# %%
# Standardize the features
X = StandardScaler().fit_transform(X)

# %%
X = torch.FloatTensor(X)
y = torch.FloatTensor(y)

dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=10, shuffle=True)

# %%
# !pip uninstall mpmath --break-system-packages -y
# Out:
# Found existing installation: mpmath 1.3.0
# Uninstalling mpmath-1.3.0:
#   Successfully uninstalled mpmath-1.3.0

# %%
import mpmath
print(mpmath.__file__)
# Out:
# /home/shk/.local/lib/python3.14/site-packages/mpmath/__init__.py

# %%
model = nn.Sequential(
    nn.Linear(30, 16),
    nn.ReLU(),
    nn.Linear(16, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()
)

criterion = nn.MSELoss()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

num_epochs = 10
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 12
#       1 model = nn.Sequential(
#       2     nn.Linear(30, 16),
#       3     nn.ReLU(),
#    (...)      7     nn.Sigmoid()
#       8 )
#      10 criterion = nn.MSELoss()
# ---> 12 optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
#      14 num_epochs = 10
#
# File /usr/lib/python3.14/site-packages/torch/optim/sgd.py:65, in SGD.__init__(self, params, lr, momentum, dampening, weight_decay, nesterov, maximize, foreach, differentiable, fused)
#      63 if nesterov and (momentum <= 0 or dampening != 0):
#      64     raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# ---> 65 super().__init__(params, defaults)
#      67 if fused:
#      68     self._step_supports_amp_scaling = True
#
# File /usr/lib/python3.14/site-packages/torch/optim/optimizer.py:408, in Optimizer.__init__(self, params, defaults)
#     405     param_groups = [{"params": param_groups}]
#     407 for param_group in param_groups:
# --> 408     self.add_param_group(cast(dict, param_group))
#     410 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     411 # which I don't think exists
#     412 # https://github.com/pytorch/pytorch/issues/72948
#     413 self._warned_capturable_if_run_uncaptured = True
#
# File /usr/lib/python3.14/site-packages/torch/_compile.py:47, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      45 disable_fn = getattr(fn, "__dynamo_disable", None)
#      46 if disable_fn is None:
# ---> 47     import torch._dynamo
#      49     # We can safely turn off functools.wraps here because the inner
#      50     # already wraps fn in the outer scope.
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#      22 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/aot_compile.py:14
#      12 import torch
#      13 import torch.fx
# ---> 14 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      15 from torch._dynamo.graph_utils import _graph_device_type
#      16 from torch._dynamo.package import SystemInfo
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/convert_frame.py:60
#      58 from torch._dynamo.callback import CallbackTrigger
#      59 from torch._dynamo.distributed import get_compile_pg
# ---> 60 from torch._dynamo.symbolic_convert import TensorifyState
#      61 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      62 from torch._logging import structured
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/symbolic_convert.py:53
#      51 import torch
#      52 import torch._logging
# ---> 53 from torch._dynamo.exc import ObservedException, TensorifyScalarRestartAnalysis
#      54 from torch._guards import tracing, TracingContext
#      55 from torch._logging.structured import dump_file
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/exc.py:44
#      41 from torch._utils_internal import get_file_path_2
#      43 from . import config
# ---> 44 from .utils import counters
#      47 if TYPE_CHECKING:
#      48     import types
#
# File /usr/lib/python3.14/site-packages/torch/_dynamo/utils.py:69
#      67 import torch
#      68 import torch._functorch.config
# ---> 69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#      71 from torch import fx
#
# File /usr/lib/python3.14/site-packages/torch/fx/experimental/symbolic_shapes.py:3
#       1 from __future__ import annotations
# ----> 3 import sympy
#       4 from sympy import S
#       6 from torch._prims_common import BoolLike, FloatLike, IntLike
#
# File /usr/lib/python3.14/site-packages/sympy/__init__.py:55
#      51 # Fails py2 test if using type hinting
#      52 SYMPY_DEBUG = __sympy_debug()  # type: bool
# ---> 55 from .core import (sympify, SympifyError, cacheit, Basic, Atom,
#      56         preorder_traversal, S, Expr, AtomicExpr, UnevaluatedExpr, Symbol,
#      57         Wild, Dummy, symbols, var, Number, Float, Rational, Integer,
#      58         NumberSymbol, RealNumber, igcd, ilcm, seterr, E, I, nan, oo, pi, zoo,
#      59         AlgebraicNumber, comp, mod_inverse, Pow, integer_nthroot, integer_log,
#      60         trailing, Mul, prod, Add, Mod, Rel, Eq, Ne, Lt, Le, Gt, Ge, Equality,
#      61         GreaterThan, LessThan, Unequality, StrictGreaterThan, StrictLessThan,
#      62         vectorize, Lambda, WildFunction, Derivative, diff, FunctionClass,
#      63         Function, Subs, expand, PoleError, count_ops, expand_mul, expand_log,
#      64         expand_func, expand_trig, expand_complex, expand_multinomial, nfloat,
#      65         expand_power_base, expand_power_exp, arity, PrecisionExhausted, N,
#      66         evalf, Tuple, Dict, gcd_terms, factor_terms, factor_nc, evaluate,
#      67         Catalan, EulerGamma, GoldenRatio, TribonacciConstant, bottom_up, use,
#      68         postorder_traversal, default_sort_key, ordered, num_digits)
#      70 from .logic import (to_cnf, to_dnf, to_nnf, And, Or, Not, Xor, Nand, Nor,
#      71         Implies, Equivalent, ITE, POSform, SOPform, simplify_logic, bool_map,
#      72         true, false, satisfiable)
#      74 from .assumptions import (AppliedPredicate, Predicate, AssumptionsContext,
#      75         assuming, Q, ask, register_handler, remove_handler, refine)
#
# File /usr/lib/python3.14/site-packages/sympy/core/__init__.py:9
#       7 from .basic import Basic, Atom
#       8 from .singleton import S
# ----> 9 from .expr import Expr, AtomicExpr, UnevaluatedExpr
#      10 from .symbol import Symbol, Wild, Dummy, symbols, var
#      11 from .numbers import Number, Float, Rational, Integer, NumberSymbol, \
#      12     RealNumber, igcd, ilcm, seterr, E, I, nan, oo, pi, zoo, \
#      13     AlgebraicNumber, comp, mod_inverse
#
# File /usr/lib/python3.14/site-packages/sympy/core/expr.py:11
#       9 from .basic import Basic, Atom
#      10 from .singleton import S
# ---> 11 from .evalf import EvalfMixin, pure_complex, DEFAULT_MAXPREC
#      12 from .decorators import call_highest_priority, sympify_method_args, sympify_return
#      13 from .cache import cacheit
#
# File /usr/lib/python3.14/site-packages/sympy/core/evalf.py:14
#      11 from mpmath import (
#      12     make_mpc, make_mpf, mp, mpc, mpf, nsum, quadts, quadosc, workprec)
#      13 from mpmath import inf as mpmath_inf
# ---> 14 from mpmath.libmp import (from_int, from_man_exp, from_rational, fhalf,
#      15                           fnan, finf, fninf, fnone, fone, fzero, mpf_abs, mpf_add,
#      16                           mpf_atan, mpf_atan2, mpf_cmp, mpf_cos, mpf_e, mpf_exp, mpf_ln, mpf_lt,
#      17                           mpf_mul, mpf_neg, mpf_pi, mpf_pow, mpf_pow_int, mpf_shift, mpf_sin,
#      18                           mpf_sqrt, normalize, round_nearest, to_int, to_str, mpf_tan)
#      19 from mpmath.libmp.backend import MPZ
#      20 from mpmath.libmp.libmpc import _infs_nan
#
# ImportError: cannot import name 'mpf_ln' from 'mpmath.libmp' (/home/shk/.local/lib/python3.14/site-packages/mpmath/libmp/__init__.py)

# %%
for epoch in range(num_epochs):
    for batch_idx, (X, y) in enumerate(dataloader):
        # model.train()
        
        optimizer.zero_grad()
        pred = model(X)
        
        loss = criterion(pred,y)
        loss.backward()
        optimizer.step()
        print(f'Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item()}')

# %%
# validation loader
X_val = val_df.drop('sus_label', axis=1).values
y_val = val_df['sus_label'].values

X_val = StandardScaler().fit_transform(X_val)
X_val = torch.FloatTensor(X_val)
y_val = torch.FloatTensor(y_val)

val_dataset = TensorDataset(X_val, y_val)
val_dataloader = DataLoader(val_dataset, batch_size=10, shuffle=False)

# %%
# Set the model to evaluation mode
model.eval()
validation_loss = 0.0

with torch.no_grad():
  for features, labels in validationloader:
      outputs = model(features)
      loss = criterion(outputs, labels)
      # Sum the current loss to the validation_loss variable
      validation_loss += loss.item()
      
# Calculate the mean loss value
validation_loss_epoch = validation_loss/len(validationloader)
print(validation_loss_epoch)

# Set the model back to training mode
model.train()

# %%
# Create accuracy metric
metric = Accuracy(task="multiclass", num_classes=3)
for features, labels in dataloader:
    outputs = model(features)
    
    # Calculate accuracy over the batch
    metric.update(outputs, labels.int())  # Convert labels to int for accuracy calculation
    
# Calculate accuracy over the whole epoch
accuracy = metric.compute()
print(f"Accuracy on all data: {accuracy}")

# Reset metric for the next epoch
metric.reset()
